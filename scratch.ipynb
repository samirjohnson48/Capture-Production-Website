# %%
import pandas as pd
import os
import requests
import json
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[95], line 5
#       3 import requests
#       4 import json
# ----> 5 from pandas import geopandas
#
# ImportError: cannot import name 'geopandas' from 'pandas' (/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/__init__.py)

# %%
datasets = os.path.join(os.getcwd(), 'data', 'csv')

asfis = pd.read_csv(os.path.join(datasets, 'ASFIS_sp_2025.csv'))
prod = pd.read_csv(os.path.join(datasets, 'FAO_global_production.csv'))
isscaap = pd.read_csv(os.path.join(datasets, 'ISSCAAP.csv'))
# Out:
# /var/folders/3h/wffpfgs16x35fp5xl_dt66mm0000gn/T/ipykernel_7360/72138631.py:4: DtypeWarning: Columns (79) have mixed types. Specify dtype option on import or set low_memory=False.
#   prod = pd.read_csv(os.path.join(datasets, 'FAO_global_production.csv'))

# %%
with open
